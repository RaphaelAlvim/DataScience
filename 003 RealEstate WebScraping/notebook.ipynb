# %% [markdown]
# ## Code Description and Objective
#
# This script is part of a set of web scraping scripts developed to consolidate key information into a robust dataset focused on the real estate market. The dataset is designed to provide strategic insights that support investment decision-making by analyzing trends and economic data related to the real estate sector.
#
# This particular script automates the collection of Euribor rates for the strategic months of June and November each year. These rates are crucial for understanding the dynamics of the credit market, a cornerstone of real estate market.

# %%
from scripts import get_euribor_annual_rates as euribor

# %%
euribor.get_euribor_annual_rates(10)
# Out:
# Fetching data for the year 2015...
# Fetching data for the year 2016...
# Fetching data for the year 2017...
# Fetching data for the year 2018...
# Fetching data for the year 2019...
# Fetching data for the year 2020...
# Fetching data for the year 2021...
# Fetching data for the year 2022...
# Fetching data for the year 2023...
# Fetching data for the year 2024...
#
# The generated DataFrame was saved as 'df_euribor'
# The CSV file was saved at: #filepath
#
# DataFrame successfully generated! Displaying first rows:
#
#    Year  Month  Annual Euribor Rate
# 0  2024     11                2.629
# 1  2024      6                3.722
# 2  2023     11                4.044
# 3  2023      6                3.875
# 4  2022     11                2.686
#     Year  Month  Annual Euribor Rate
# 0   2024     11                2.629
# 1   2024      6                3.722
# 2   2023     11                4.044
# 3   2023      6                3.875
# 4   2022     11                2.686
# ...
